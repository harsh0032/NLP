# %%
pip install fer
# Out:
# Collecting fer
#   Using cached fer-22.4.0-py3-none-any.whl (812 kB)
# Collecting mtcnn>=0.1.1
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 1.4 MB/s eta 0:00:0000:0100:010m
# Collecting keras>=2.0.0
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: requests in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from fer) (2.28.1)
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.6.0.66-cp37-abi3-macosx_11_0_arm64.whl (38.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 1.2 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: matplotlib in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from fer) (3.5.0)
# Requirement already satisfied: tqdm in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from fer) (4.64.0)
# Collecting opencv-python>=4.1.0
#   Downloading opencv_python-4.6.0.66-cp37-abi3-macosx_11_0_arm64.whl (30.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.0/30.0 MB 1.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.17 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->fer) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->fer) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->fer) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->fer) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->fer) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->fer) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->fer) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib->fer) (2.8.2)
# Collecting numpy>=1.17
#   Downloading numpy-1.23.1-cp39-cp39-macosx_11_0_arm64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 2.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from requests->fer) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from requests->fer) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from requests->fer) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from requests->fer) (1.26.9)
# Requirement already satisfied: six>=1.5 in /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->fer) (1.15.0)
# Installing collected packages: keras, numpy, opencv-python, opencv-contrib-python, mtcnn, fer
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.5.0 requires numpy~=1.19.2, but you have numpy 1.23.1 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.1 which is incompatible.
# Successfully installed fer-22.4.0 keras-2.9.0 mtcnn-0.1.1 numpy-1.23.1 opencv-contrib-python-4.6.0.66 opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
from fer import FER
import matplotlib.pyplot as plt 
# %matplotlib inline

test_image_one = plt.imread("tmp_306d9ad6-210c-4907-88e1-a97945248558.jpeg")
emo_detector = FER(mtcnn=True)
# Capture all the emotions on the image
captured_emotions = emo_detector.detect_emotions(test_image_one)
# Print all captured emotions with the image
print(captured_emotions)
plt.imshow(test_image_one)
# Out:
# /Users/harshchauhan/miniforge3/envs/tensorflow/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# Metal device set to: Apple M1
# 2022-08-10 14:42:52.456710: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-08-10 14:42:52.457039: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-08-10 14:42:53.311230: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-08-10 14:42:53.314394: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-08-10 14:42:53.362232: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 14:42:53.927322: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 14:42:54.093447: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 14:42:54.899570: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 14:42:55.723880: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# [{'box': [133, 47, 214, 293], 'emotions': {'angry': 0.01, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.01, 'sad': 0.01, 'surprise': 0.0, 'neutral': 0.97}}]

# %%
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_one)
print(dominant_emotion, emotion_score)
# Out:
# neutral 0.97

# %%
test_image_three = plt.imread("tmp_d7145f81-e1e1-48af-9de7-bade7f814d29.jpeg")
captured_emotions_three = emo_detector.detect_emotions(test_image_three)
print(captured_emotions_three)
plt.imshow(test_image_three)
dominant_emotion_three, emotion_score_three = emo_detector.top_emotion(test_image_three)
print(dominant_emotion_three, emotion_score_three)
# Out:
# [{'box': [46, 48, 78, 110], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.98, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.01}}]
# happy 0.98

# %%
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_three)
print(dominant_emotion, emotion_score)
# Out:
# happy 0.98

# %%
test_image_four = plt.imread("tmp_17515bb4-c5b0-4cde-b991-7d71f34bc0ea.jpeg")
captured_emotions_three = emo_detector.detect_emotions(test_image_three)
print(captured_emotions_three)
plt.imshow(test_image_three)
dominant_emotion_three, emotion_score_three = emo_detector.top_emotion(test_image_three)
print(dominant_emotion_three, emotion_score_three)
# Out:
# [{'box': [169, 75, 199, 237], 'emotions': {'angry': 0.77, 'disgust': 0.0, 'fear': 0.14, 'happy': 0.0, 'sad': 0.04, 'surprise': 0.01, 'neutral': 0.04}}]
# angry 0.77

# %%
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_four)
print(dominant_emotion, emotion_score)
# Out:
# angry 0.77

# %%
from fer import Video
from fer import FER
video_filename = "Video_One.mp4"
video = Video(video_filename)
# Analyze video, displaying the output
detector = FER(mtcnn=True)
video.analyze(detector, display=True)
# Out:
# INFO:fer:30.00 fps, 583 frames, 19.43 seconds
# INFO:fer:Making directories at output
#   0%|                                               | 0/583 [00:00<?, ?frames/s]2022-08-10 14:55:01.329164: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 14:55:01.508479: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 14:55:01.602030: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 14:55:02.258913: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 14:55:02.338132: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 100%|█████████████████████████████████████| 583/583 [04:13<00:00,  2.30frames/s]
# INFO:fer:Completed analysis: saved to output/Video_One_output.mp4
# INFO:fer:Starting to Zip
# INFO:fer:Compressing: 8%
# INFO:fer:Compressing: 17%
# INFO:fer:Compressing: 25%
# INFO:fer:Compressing: 34%
# INFO:fer:Compressing: 42%
# INFO:fer:Compressing: 51%
# INFO:fer:Compressing: 60%
# INFO:fer:Compressing: 68%
# INFO:fer:Compressing: 77%
# INFO:fer:Compressing: 85%
# INFO:fer:Compressing: 94%
# INFO:fer:Zip has finished
# [{'box0': [776, 265, 295, 371],
#   'angry0': 0.3,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.06,
#   'neutral0': 0.26},
#  {'box0': [776, 265, 295, 371],
#   'angry0': 0.3,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.06,
#   'neutral0': 0.27},
#  {'box0': [776, 265, 295, 371],
#   'angry0': 0.3,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.06,
#   'neutral0': 0.27},
#  {'box0': [777, 265, 293, 369],
#   'angry0': 0.28,
#   'disgust0': 0.0,
#   'fear0': 0.21,
#   'happy0': 0.0,
#   'sad0': 0.2,
#   'surprise0': 0.05,
#   'neutral0': 0.25},
#  {'box0': [777, 265, 294, 370],
#   'angry0': 0.32,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.24,
#   'surprise0': 0.04,
#   'neutral0': 0.23},
#  {'box0': [779, 265, 291, 368],
#   'angry0': 0.26,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.21,
#   'surprise0': 0.03,
#   'neutral0': 0.32},
#  {'box0': [779, 265, 291, 368],
#   'angry0': 0.26,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.21,
#   'surprise0': 0.03,
#   'neutral0': 0.32},
#  {'box0': [779, 265, 291, 368],
#   'angry0': 0.26,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.21,
#   'surprise0': 0.03,
#   'neutral0': 0.32},
#  {'box0': [777, 268, 290, 366],
#   'angry0': 0.06,
#   'disgust0': 0.0,
#   'fear0': 0.21,
#   'happy0': 0.0,
#   'sad0': 0.45,
#   'surprise0': 0.0,
#   'neutral0': 0.27},
#  {'box0': [777, 268, 290, 366],
#   'angry0': 0.06,
#   'disgust0': 0.0,
#   'fear0': 0.21,
#   'happy0': 0.0,
#   'sad0': 0.45,
#   'surprise0': 0.0,
#   'neutral0': 0.28},
#  {'box0': [777, 267, 290, 366],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.21,
#   'happy0': 0.0,
#   'sad0': 0.29,
#   'surprise0': 0.0,
#   'neutral0': 0.31},
#  {'box0': [777, 268, 289, 364],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.28},
#  {'box0': [777, 268, 289, 364],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.28},
#  {'box0': [777, 267, 293, 367],
#   'angry0': 0.22,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.25,
#   'surprise0': 0.02,
#   'neutral0': 0.26},
#  {'box0': [777, 267, 293, 367],
#   'angry0': 0.23,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.25,
#   'surprise0': 0.02,
#   'neutral0': 0.26},
#  {'box0': [778, 266, 291, 367],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.22,
#   'surprise0': 0.02,
#   'neutral0': 0.32},
#  {'box0': [778, 266, 291, 367],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.22,
#   'surprise0': 0.02,
#   'neutral0': 0.32},
#  {'box0': [778, 266, 291, 367],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.22,
#   'surprise0': 0.02,
#   'neutral0': 0.32},
#  {'box0': [780, 266, 288, 366],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.29,
#   'surprise0': 0.02,
#   'neutral0': 0.32},
#  {'box0': [779, 267, 289, 364],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.02,
#   'neutral0': 0.29},
#  {'box0': [777, 266, 292, 367],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.27,
#   'surprise0': 0.03,
#   'neutral0': 0.27},
#  {'box0': [777, 266, 292, 367],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.27,
#   'surprise0': 0.03,
#   'neutral0': 0.27},
#  {'box0': [777, 266, 292, 367],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.27,
#   'surprise0': 0.03,
#   'neutral0': 0.27},
#  {'box0': [775, 256, 288, 384],
#   'angry0': 0.23,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.26,
#   'surprise0': 0.04,
#   'neutral0': 0.25},
#  {'box0': [775, 256, 288, 384],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.21,
#   'happy0': 0.0,
#   'sad0': 0.26,
#   'surprise0': 0.04,
#   'neutral0': 0.25},
#  {'box0': [774, 257, 288, 382],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.24,
#   'surprise0': 0.04,
#   'neutral0': 0.27},
#  {'box0': [774, 256, 287, 382],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.18,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.03,
#   'neutral0': 0.29},
#  {'box0': [774, 256, 287, 382],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.18,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.03,
#   'neutral0': 0.29},
#  {'box0': [779, 264, 284, 370],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.23,
#   'surprise0': 0.05,
#   'neutral0': 0.26},
#  {'box0': [779, 264, 284, 370],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.23,
#   'surprise0': 0.05,
#   'neutral0': 0.26},
#  {'box0': [768, 262, 296, 372],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.06,
#   'neutral0': 0.46},
#  {'box0': [768, 261, 296, 373],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.06,
#   'neutral0': 0.43},
#  {'box0': [768, 261, 296, 373],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.06,
#   'neutral0': 0.43},
#  {'box0': [774, 250, 286, 390],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.1,
#   'neutral0': 0.35},
#  {'box0': [774, 250, 286, 391],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.12,
#   'neutral0': 0.33},
#  {'box0': [775, 256, 283, 371],
#   'angry0': 0.21,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.19,
#   'surprise0': 0.05,
#   'neutral0': 0.31},
#  {'box0': [775, 250, 285, 384],
#   'angry0': 0.22,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.1,
#   'neutral0': 0.29},
#  {'box0': [775, 250, 285, 384],
#   'angry0': 0.22,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.1,
#   'neutral0': 0.29},
#  {'box0': [777, 256, 279, 370],
#   'angry0': 0.25,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.07,
#   'neutral0': 0.32},
#  {'box0': [776, 256, 280, 370],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.21,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.06,
#   'neutral0': 0.31},
#  {'box0': [775, 256, 281, 369],
#   'angry0': 0.22,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.19,
#   'surprise0': 0.08,
#   'neutral0': 0.28},
#  {'box0': [776, 256, 280, 369],
#   'angry0': 0.21,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.06,
#   'neutral0': 0.33},
#  {'box0': [776, 256, 280, 369],
#   'angry0': 0.21,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.06,
#   'neutral0': 0.33},
#  {'box0': [778, 250, 279, 381],
#   'angry0': 0.21,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.01,
#   'sad0': 0.19,
#   'surprise0': 0.08,
#   'neutral0': 0.33},
#  {'box0': [778, 250, 279, 381],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.01,
#   'sad0': 0.18,
#   'surprise0': 0.08,
#   'neutral0': 0.34},
#  {'box0': [778, 249, 279, 382],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.01,
#   'sad0': 0.14,
#   'surprise0': 0.08,
#   'neutral0': 0.41},
#  {'box0': [778, 249, 279, 382],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.01,
#   'sad0': 0.14,
#   'surprise0': 0.08,
#   'neutral0': 0.41},
#  {'box0': [778, 249, 279, 382],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.01,
#   'sad0': 0.14,
#   'surprise0': 0.08,
#   'neutral0': 0.41},
#  {'box0': [780, 250, 278, 381],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.01,
#   'sad0': 0.17,
#   'surprise0': 0.12,
#   'neutral0': 0.34},
#  {'box0': [780, 250, 278, 381],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.01,
#   'sad0': 0.17,
#   'surprise0': 0.11,
#   'neutral0': 0.34},
#  {'box0': [783, 252, 277, 379],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.07,
#   'neutral0': 0.34},
#  {'box0': [783, 252, 277, 379],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.07,
#   'neutral0': 0.34},
#  {'box0': [783, 252, 277, 379],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.07,
#   'neutral0': 0.34},
#  {'box0': [780, 259, 277, 363],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.25,
#   'surprise0': 0.05,
#   'neutral0': 0.26},
#  {'box0': [779, 259, 279, 363],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.25,
#   'surprise0': 0.05,
#   'neutral0': 0.26},
#  {'box0': [778, 271, 279, 349],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.31,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.29},
#  {'box0': [778, 271, 279, 349],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.31,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.29},
#  {'box0': [778, 271, 279, 349],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.31,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.28},
#  {'box0': [776, 262, 288, 363],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.27,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.29},
#  {'box0': [776, 262, 288, 363],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.3},
#  {'box0': [778, 267, 284, 357],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.23,
#   'surprise0': 0.01,
#   'neutral0': 0.27},
#  {'box0': [779, 268, 283, 354],
#   'angry0': 0.23,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.21,
#   'surprise0': 0.01,
#   'neutral0': 0.29},
#  {'box0': [779, 268, 283, 354],
#   'angry0': 0.23,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.21,
#   'surprise0': 0.01,
#   'neutral0': 0.29},
#  {'box0': [782, 270, 282, 353],
#   'angry0': 0.32,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.01,
#   'neutral0': 0.22},
#  {'box0': [781, 270, 283, 353],
#   'angry0': 0.31,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.02,
#   'neutral0': 0.22},
#  {'box0': [784, 271, 281, 351],
#   'angry0': 0.34,
#   'disgust0': 0.0,
#   'fear0': 0.32,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.02,
#   'neutral0': 0.17},
#  {'box0': [784, 272, 281, 350],
#   'angry0': 0.36,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.01,
#   'neutral0': 0.17},
#  {'box0': [784, 272, 281, 350],
#   'angry0': 0.36,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.01,
#   'neutral0': 0.17},
#  {'box0': [784, 271, 282, 352],
#   'angry0': 0.33,
#   'disgust0': 0.0,
#   'fear0': 0.34,
#   'happy0': 0.0,
#   'sad0': 0.14,
#   'surprise0': 0.02,
#   'neutral0': 0.18},
#  {'box0': [784, 271, 282, 352],
#   'angry0': 0.32,
#   'disgust0': 0.0,
#   'fear0': 0.35,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.02,
#   'neutral0': 0.18},
#  {'box0': [785, 272, 279, 350],
#   'angry0': 0.34,
#   'disgust0': 0.0,
#   'fear0': 0.33,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.02,
#   'neutral0': 0.19},
#  {'box0': [785, 272, 279, 350],
#   'angry0': 0.33,
#   'disgust0': 0.0,
#   'fear0': 0.33,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.02,
#   'neutral0': 0.2},
#  {'box0': [785, 272, 279, 350],
#   'angry0': 0.33,
#   'disgust0': 0.0,
#   'fear0': 0.33,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.02,
#   'neutral0': 0.2},
#  {'box0': [778, 262, 289, 363],
#   'angry0': 0.36,
#   'disgust0': 0.0,
#   'fear0': 0.28,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.03,
#   'neutral0': 0.19},
#  {'box0': [778, 262, 290, 364],
#   'angry0': 0.38,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.14,
#   'surprise0': 0.03,
#   'neutral0': 0.21},
#  {'box0': [778, 261, 289, 364],
#   'angry0': 0.32,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.14,
#   'surprise0': 0.04,
#   'neutral0': 0.29},
#  {'box0': [778, 261, 288, 364],
#   'angry0': 0.35,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.04,
#   'neutral0': 0.24},
#  {'box0': [778, 261, 288, 364],
#   'angry0': 0.35,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.04,
#   'neutral0': 0.24},
#  {'box0': [782, 271, 284, 354],
#   'angry0': 0.41,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.04,
#   'neutral0': 0.16},
#  {'box0': [782, 271, 284, 354],
#   'angry0': 0.41,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.04,
#   'neutral0': 0.16},
#  {'box0': [783, 278, 281, 351],
#   'angry0': 0.45,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.03,
#   'neutral0': 0.15},
#  {'box0': [783, 278, 281, 351],
#   'angry0': 0.45,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.03,
#   'neutral0': 0.14},
#  {'box0': [783, 278, 281, 351],
#   'angry0': 0.45,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.03,
#   'neutral0': 0.14},
#  {'box0': [777, 263, 298, 374],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.17,
#   'surprise0': 0.06,
#   'neutral0': 0.31},
#  {'box0': [777, 264, 298, 373],
#   'angry0': 0.25,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.17,
#   'surprise0': 0.08,
#   'neutral0': 0.26},
#  {'box0': [777, 265, 298, 373],
#   'angry0': 0.28,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.08,
#   'neutral0': 0.23},
#  {'box0': [777, 265, 298, 373],
#   'angry0': 0.27,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.08,
#   'neutral0': 0.23},
#  {'box0': [777, 265, 298, 373],
#   'angry0': 0.27,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.08,
#   'neutral0': 0.23},
#  {'box0': [777, 263, 298, 376],
#   'angry0': 0.25,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.08,
#   'neutral0': 0.31},
#  {'box0': [777, 263, 298, 376],
#   'angry0': 0.25,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.08,
#   'neutral0': 0.31},
#  {'box0': [782, 282, 289, 364],
#   'angry0': 0.22,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.08,
#   'neutral0': 0.29},
#  {'box0': [782, 283, 289, 364],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.06,
#   'neutral0': 0.37},
#  {'box0': [782, 283, 289, 364],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.06,
#   'neutral0': 0.37},
#  {'box0': [777, 261, 296, 376],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.21,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.09,
#   'neutral0': 0.42},
#  {'box0': [777, 261, 295, 376],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.1,
#   'neutral0': 0.41},
#  {'box0': [784, 263, 282, 373],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.14,
#   'neutral0': 0.26},
#  {'box0': [784, 262, 281, 374],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.14,
#   'neutral0': 0.33},
#  {'box0': [784, 262, 281, 374],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.14,
#   'neutral0': 0.33},
#  {'box0': [780, 252, 285, 390],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.15,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.12,
#   'neutral0': 0.43},
#  {'box0': [780, 252, 285, 390],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.15,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.12,
#   'neutral0': 0.43},
#  {'box0': [776, 266, 295, 373],
#   'angry0': 0.27,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.14,
#   'surprise0': 0.06,
#   'neutral0': 0.34},
#  {'box0': [781, 257, 280, 382],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.13,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.06,
#   'neutral0': 0.45},
#  {'box0': [781, 257, 280, 382],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.13,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.06,
#   'neutral0': 0.45},
#  {'box0': [784, 264, 283, 371],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.1,
#   'surprise0': 0.13,
#   'neutral0': 0.34},
#  {'box0': [784, 264, 283, 371],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.12,
#   'neutral0': 0.35},
#  {'box0': [781, 283, 289, 366],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.03,
#   'neutral0': 0.56},
#  {'box0': [781, 283, 289, 366],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.03,
#   'neutral0': 0.56},
#  {'box0': [781, 283, 289, 366],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.03,
#   'neutral0': 0.56},
#  {'box0': [781, 268, 291, 367],
#   'angry0': 0.3,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.12,
#   'neutral0': 0.24},
#  {'box0': [781, 267, 291, 368],
#   'angry0': 0.3,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.12,
#   'neutral0': 0.24},
#  {'box0': [781, 268, 290, 365],
#   'angry0': 0.4,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.17,
#   'surprise0': 0.08,
#   'neutral0': 0.18},
#  {'box0': [781, 268, 290, 365],
#   'angry0': 0.41,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.17,
#   'surprise0': 0.08,
#   'neutral0': 0.18},
#  {'box0': [781, 268, 290, 365],
#   'angry0': 0.41,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.17,
#   'surprise0': 0.08,
#   'neutral0': 0.18},
#  {'box0': [778, 263, 289, 366],
#   'angry0': 0.37,
#   'disgust0': 0.0,
#   'fear0': 0.11,
#   'happy0': 0.0,
#   'sad0': 0.19,
#   'surprise0': 0.06,
#   'neutral0': 0.27},
#  {'box0': [778, 263, 289, 366],
#   'angry0': 0.37,
#   'disgust0': 0.0,
#   'fear0': 0.11,
#   'happy0': 0.0,
#   'sad0': 0.19,
#   'surprise0': 0.06,
#   'neutral0': 0.27},
#  {'box0': [780, 260, 284, 360],
#   'angry0': 0.31,
#   'disgust0': 0.0,
#   'fear0': 0.05,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.02,
#   'neutral0': 0.32},
#  {'box0': [780, 261, 284, 361],
#   'angry0': 0.28,
#   'disgust0': 0.0,
#   'fear0': 0.06,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.02,
#   'neutral0': 0.34},
#  {'box0': [780, 261, 284, 361],
#   'angry0': 0.28,
#   'disgust0': 0.0,
#   'fear0': 0.06,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.02,
#   'neutral0': 0.34},
#  {'box0': [789, 269, 275, 351],
#   'angry0': 0.36,
#   'disgust0': 0.0,
#   'fear0': 0.08,
#   'happy0': 0.0,
#   'sad0': 0.22,
#   'surprise0': 0.03,
#   'neutral0': 0.31},
#  {'box0': [789, 269, 275, 351],
#   'angry0': 0.35,
#   'disgust0': 0.0,
#   'fear0': 0.08,
#   'happy0': 0.0,
#   'sad0': 0.22,
#   'surprise0': 0.03,
#   'neutral0': 0.31},
#  {'box0': [793, 279, 271, 342],
#   'angry0': 0.51,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.09,
#   'surprise0': 0.08,
#   'neutral0': 0.15},
#  {'box0': [793, 279, 270, 342],
#   'angry0': 0.51,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.0,
#   'sad0': 0.09,
#   'surprise0': 0.08,
#   'neutral0': 0.16},
#  {'box0': [793, 279, 270, 342],
#   'angry0': 0.51,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.0,
#   'sad0': 0.09,
#   'surprise0': 0.08,
#   'neutral0': 0.16},
#  {'box0': [788, 267, 288, 381],
#   'angry0': 0.43,
#   'disgust0': 0.0,
#   'fear0': 0.16,
#   'happy0': 0.0,
#   'sad0': 0.05,
#   'surprise0': 0.19,
#   'neutral0': 0.17},
#  {'box0': [789, 269, 287, 378],
#   'angry0': 0.36,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.05,
#   'surprise0': 0.23,
#   'neutral0': 0.15},
#  {'box0': [796, 271, 278, 369],
#   'angry0': 0.37,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.29,
#   'neutral0': 0.09},
#  {'box0': [796, 271, 278, 369],
#   'angry0': 0.37,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.29,
#   'neutral0': 0.09},
#  {'box0': [796, 271, 278, 369],
#   'angry0': 0.37,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.29,
#   'neutral0': 0.09},
#  {'box0': [793, 272, 283, 368],
#   'angry0': 0.41,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.21,
#   'neutral0': 0.11},
#  {'box0': [793, 271, 283, 369],
#   'angry0': 0.42,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.21,
#   'neutral0': 0.12},
#  {'box0': [784, 265, 293, 376],
#   'angry0': 0.38,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.05,
#   'neutral0': 0.22},
#  {'box0': [784, 265, 293, 376],
#   'angry0': 0.38,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.05,
#   'neutral0': 0.22},
#  {'box0': [784, 265, 293, 376],
#   'angry0': 0.38,
#   'disgust0': 0.0,
#   'fear0': 0.24,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.05,
#   'neutral0': 0.22},
#  {'box0': [792, 279, 271, 344],
#   'angry0': 0.48,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.06,
#   'neutral0': 0.16},
#  {'box0': [792, 279, 272, 345],
#   'angry0': 0.46,
#   'disgust0': 0.0,
#   'fear0': 0.18,
#   'happy0': 0.0,
#   'sad0': 0.11,
#   'surprise0': 0.07,
#   'neutral0': 0.19},
#  {'box0': [793, 279, 272, 344],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.24,
#   'surprise0': 0.01,
#   'neutral0': 0.37},
#  {'box0': [793, 279, 272, 344],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.23,
#   'surprise0': 0.01,
#   'neutral0': 0.37},
#  {'box0': [793, 279, 272, 344],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.19,
#   'happy0': 0.0,
#   'sad0': 0.23,
#   'surprise0': 0.01,
#   'neutral0': 0.37},
#  {'box0': [786, 273, 280, 362],
#   'angry0': 0.31,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.0,
#   'neutral0': 0.31},
#  {'box0': [786, 273, 280, 362],
#   'angry0': 0.3,
#   'disgust0': 0.0,
#   'fear0': 0.23,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.0,
#   'neutral0': 0.32},
#  {'box0': [785, 270, 284, 357],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.33,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.01,
#   'neutral0': 0.25},
#  {'box0': [786, 270, 283, 357],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.34,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.01,
#   'neutral0': 0.25},
#  {'box0': [786, 270, 283, 357],
#   'angry0': 0.24,
#   'disgust0': 0.0,
#   'fear0': 0.34,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.01,
#   'neutral0': 0.25},
#  {'box0': [789, 263, 284, 359],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.18,
#   'happy0': 0.0,
#   'sad0': 0.37,
#   'surprise0': 0.01,
#   'neutral0': 0.3},
#  {'box0': [789, 262, 283, 360],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.21,
#   'happy0': 0.0,
#   'sad0': 0.38,
#   'surprise0': 0.01,
#   'neutral0': 0.26},
#  {'box0': [790, 263, 284, 360],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.02,
#   'neutral0': 0.31},
#  {'box0': [790, 263, 284, 360],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.02,
#   'neutral0': 0.31},
#  {'box0': [790, 263, 284, 360],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.2,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.02,
#   'neutral0': 0.31},
#  {'box0': [791, 264, 284, 358],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.02,
#   'neutral0': 0.3},
#  {'box0': [791, 264, 284, 358],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.17,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.02,
#   'neutral0': 0.3},
#  {'box0': [791, 253, 274, 343],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.35,
#   'happy0': 0.0,
#   'sad0': 0.2,
#   'surprise0': 0.02,
#   'neutral0': 0.26},
#  {'box0': [791, 252, 274, 344],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.37,
#   'happy0': 0.0,
#   'sad0': 0.17,
#   'surprise0': 0.02,
#   'neutral0': 0.27},
#  {'box0': [791, 252, 274, 343],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.35,
#   'happy0': 0.0,
#   'sad0': 0.19,
#   'surprise0': 0.03,
#   'neutral0': 0.24},
#  {'box0': [791, 252, 274, 343],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.35,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.03,
#   'neutral0': 0.24},
#  {'box0': [793, 253, 274, 343],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.42,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.02,
#   'neutral0': 0.23},
#  {'box0': [793, 253, 274, 343],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.41,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.02,
#   'neutral0': 0.23},
#  {'box0': [793, 253, 274, 343],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.42,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.02,
#   'neutral0': 0.23},
#  {'box0': [793, 251, 274, 346],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.37,
#   'happy0': 0.0,
#   'sad0': 0.17,
#   'surprise0': 0.03,
#   'neutral0': 0.26},
#  {'box0': [793, 251, 274, 346],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.36,
#   'happy0': 0.0,
#   'sad0': 0.17,
#   'surprise0': 0.03,
#   'neutral0': 0.27},
#  {'box0': [793, 252, 275, 344],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.39,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.03,
#   'neutral0': 0.24},
#  {'box0': [795, 252, 274, 344],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.38,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.02,
#   'neutral0': 0.24},
#  {'box0': [795, 252, 274, 344],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.38,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.02,
#   'neutral0': 0.24},
#  {'box0': [792, 249, 277, 347],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.07,
#   'neutral0': 0.21},
#  {'box0': [793, 249, 277, 348],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.05,
#   'neutral0': 0.18},
#  {'box0': [793, 249, 277, 348],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.48,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.06,
#   'neutral0': 0.15},
#  {'box0': [794, 249, 277, 349],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.47,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.06,
#   'neutral0': 0.16},
#  {'box0': [794, 249, 277, 349],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.47,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.06,
#   'neutral0': 0.16},
#  {'box0': [794, 251, 276, 346],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.39,
#   'happy0': 0.0,
#   'sad0': 0.14,
#   'surprise0': 0.05,
#   'neutral0': 0.24},
#  {'box0': [795, 253, 274, 343],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.4,
#   'happy0': 0.0,
#   'sad0': 0.14,
#   'surprise0': 0.06,
#   'neutral0': 0.24},
#  {'box0': [796, 253, 274, 343],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.14,
#   'surprise0': 0.05,
#   'neutral0': 0.19},
#  {'box0': [796, 253, 273, 342],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.41,
#   'happy0': 0.0,
#   'sad0': 0.17,
#   'surprise0': 0.05,
#   'neutral0': 0.21},
#  {'box0': [796, 253, 274, 343],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.14,
#   'surprise0': 0.05,
#   'neutral0': 0.19},
#  {'box0': [792, 242, 278, 354],
#   'angry0': 0.05,
#   'disgust0': 0.0,
#   'fear0': 0.33,
#   'happy0': 0.0,
#   'sad0': 0.21,
#   'surprise0': 0.0,
#   'neutral0': 0.41},
#  {'box0': [792, 242, 277, 353],
#   'angry0': 0.04,
#   'disgust0': 0.0,
#   'fear0': 0.32,
#   'happy0': 0.0,
#   'sad0': 0.21,
#   'surprise0': 0.0,
#   'neutral0': 0.42},
#  {'box0': [797, 251, 274, 345],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.26,
#   'surprise0': 0.0,
#   'neutral0': 0.3},
#  {'box0': [797, 251, 274, 345],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.26,
#   'surprise0': 0.0,
#   'neutral0': 0.3},
#  {'box0': [797, 251, 274, 345],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.26,
#   'surprise0': 0.0,
#   'neutral0': 0.3},
#  {'box0': [794, 252, 276, 343],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.19,
#   'surprise0': 0.01,
#   'neutral0': 0.32},
#  {'box0': [794, 252, 276, 343],
#   'angry0': 0.18,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.19,
#   'surprise0': 0.01,
#   'neutral0': 0.32},
#  {'box0': [796, 255, 273, 341],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.34,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.04,
#   'neutral0': 0.32},
#  {'box0': [795, 249, 277, 349],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.49,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.02,
#   'neutral0': 0.19},
#  {'box0': [795, 249, 277, 349],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.49,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.02,
#   'neutral0': 0.18},
#  {'box0': [794, 249, 277, 350],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.48,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.03,
#   'neutral0': 0.19},
#  {'box0': [794, 249, 277, 350],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.48,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.03,
#   'neutral0': 0.19},
#  {'box0': [784, 245, 282, 362],
#   'angry0': 0.21,
#   'disgust0': 0.0,
#   'fear0': 0.25,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.02,
#   'neutral0': 0.36},
#  {'box0': [795, 252, 275, 348],
#   'angry0': 0.23,
#   'disgust0': 0.0,
#   'fear0': 0.37,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.03,
#   'neutral0': 0.22},
#  {'box0': [795, 252, 275, 348],
#   'angry0': 0.23,
#   'disgust0': 0.0,
#   'fear0': 0.37,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.03,
#   'neutral0': 0.22},
#  {'box0': [795, 252, 276, 347],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.34,
#   'happy0': 0.0,
#   'sad0': 0.16,
#   'surprise0': 0.05,
#   'neutral0': 0.26},
#  {'box0': [796, 253, 275, 346],
#   'angry0': 0.23,
#   'disgust0': 0.0,
#   'fear0': 0.29,
#   'happy0': 0.0,
#   'sad0': 0.18,
#   'surprise0': 0.03,
#   'neutral0': 0.26},
#  {'box0': [786, 250, 280, 357],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.03,
#   'neutral0': 0.45},
#  {'box0': [786, 250, 280, 357],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.03,
#   'neutral0': 0.44},
#  {'box0': [786, 250, 280, 357],
#   'angry0': 0.19,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.12,
#   'surprise0': 0.03,
#   'neutral0': 0.44},
#  {'box0': [790, 253, 279, 355],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.28,
#   'happy0': 0.0,
#   'sad0': 0.15,
#   'surprise0': 0.04,
#   'neutral0': 0.39},
#  {'box0': [789, 251, 279, 357],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.29,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.03,
#   'neutral0': 0.39},
#  {'box0': [792, 252, 278, 356],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.37,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.04,
#   'neutral0': 0.26},
#  {'box0': [792, 252, 278, 356],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.37,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.04,
#   'neutral0': 0.25},
#  {'box0': [792, 252, 278, 356],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.37,
#   'happy0': 0.0,
#   'sad0': 0.13,
#   'surprise0': 0.04,
#   'neutral0': 0.25},
#  {'box0': [789, 251, 280, 357],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.09,
#   'surprise0': 0.07,
#   'neutral0': 0.22},
#  {'box0': [789, 251, 280, 357],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.09,
#   'surprise0': 0.07,
#   'neutral0': 0.22},
#  {'box0': [790, 254, 281, 357],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.54,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.27,
#   'neutral0': 0.06},
#  {'box0': [790, 254, 281, 357],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.53,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.28,
#   'neutral0': 0.06},
#  {'box0': [790, 254, 281, 357],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.53,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.28,
#   'neutral0': 0.06},
#  {'box0': [789, 252, 281, 358],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.04,
#   'surprise0': 0.21,
#   'neutral0': 0.08},
#  {'box0': [789, 252, 281, 358],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.04,
#   'surprise0': 0.21,
#   'neutral0': 0.08},
#  {'box0': [792, 254, 278, 355],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.53,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.25,
#   'neutral0': 0.03},
#  {'box0': [792, 254, 278, 355],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.54,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.25,
#   'neutral0': 0.03},
#  {'box0': [792, 254, 278, 355],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.54,
#   'happy0': 0.0,
#   'sad0': 0.03,
#   'surprise0': 0.25,
#   'neutral0': 0.03},
#  {'box0': [791, 254, 278, 356],
#   'angry0': 0.05,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.01,
#   'surprise0': 0.49,
#   'neutral0': 0.01},
#  {'box0': [790, 253, 279, 357],
#   'angry0': 0.05,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.01,
#   'surprise0': 0.48,
#   'neutral0': 0.01},
#  {'box0': [790, 253, 279, 358],
#   'angry0': 0.04,
#   'disgust0': 0.0,
#   'fear0': 0.35,
#   'happy0': 0.0,
#   'sad0': 0.0,
#   'surprise0': 0.61,
#   'neutral0': 0.0},
#  {'box0': [787, 250, 283, 362],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.42,
#   'happy0': 0.0,
#   'sad0': 0.01,
#   'surprise0': 0.5,
#   'neutral0': 0.01},
#  {'box0': [787, 251, 283, 361],
#   'angry0': 0.06,
#   'disgust0': 0.0,
#   'fear0': 0.4,
#   'happy0': 0.0,
#   'sad0': 0.0,
#   'surprise0': 0.53,
#   'neutral0': 0.01},
#  {'box0': [789, 250, 282, 362],
#   'angry0': 0.06,
#   'disgust0': 0.0,
#   'fear0': 0.32,
#   'happy0': 0.0,
#   'sad0': 0.0,
#   'surprise0': 0.61,
#   'neutral0': 0.01},
#  {'box0': [789, 250, 282, 362],
#   'angry0': 0.06,
#   'disgust0': 0.0,
#   'fear0': 0.31,
#   'happy0': 0.0,
#   'sad0': 0.0,
#   'surprise0': 0.62,
#   'neutral0': 0.01},
#  {'box0': [790, 252, 282, 360],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.0,
#   'surprise0': 0.61,
#   'neutral0': 0.01},
#  {'box0': [790, 252, 282, 360],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.0,
#   'surprise0': 0.6,
#   'neutral0': 0.01},
#  {'box0': [790, 252, 282, 360],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.0,
#   'surprise0': 0.6,
#   'neutral0': 0.01},
#  {'box0': [786, 248, 282, 351],
#   'angry0': 0.06,
#   'disgust0': 0.0,
#   'fear0': 0.22,
#   'happy0': 0.0,
#   'sad0': 0.0,
#   'surprise0': 0.71,
#   'neutral0': 0.0},
#  {'box0': [788, 249, 283, 361],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.01,
#   'surprise0': 0.57,
#   'neutral0': 0.01},
#  {'box0': [788, 250, 274, 346],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.01,
#   'surprise0': 0.59,
#   'neutral0': 0.01},
#  {'box0': [788, 250, 274, 345],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.28,
#   'happy0': 0.0,
#   'sad0': 0.01,
#   'surprise0': 0.59,
#   'neutral0': 0.01},
#  {'box0': [788, 250, 274, 346],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.26,
#   'happy0': 0.0,
#   'sad0': 0.01,
#   'surprise0': 0.59,
#   'neutral0': 0.01},
#  {'box0': [783, 241, 287, 353],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.14,
#   'happy0': 0.0,
#   'sad0': 0.01,
#   'surprise0': 0.74,
#   'neutral0': 0.01},
#  {'box0': [784, 241, 286, 353],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.12,
#   'happy0': 0.0,
#   'sad0': 0.01,
#   'surprise0': 0.74,
#   'neutral0': 0.01},
#  {'box0': [792, 235, 275, 353],
#   'angry0': 0.26,
#   'disgust0': 0.0,
#   'fear0': 0.13,
#   'happy0': 0.17,
#   'sad0': 0.02,
#   'surprise0': 0.39,
#   'neutral0': 0.03},
#  {'box0': [792, 235, 276, 353],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.15,
#   'happy0': 0.2,
#   'sad0': 0.02,
#   'surprise0': 0.41,
#   'neutral0': 0.02},
#  {'box0': [792, 235, 276, 353],
#   'angry0': 0.2,
#   'disgust0': 0.0,
#   'fear0': 0.15,
#   'happy0': 0.2,
#   'sad0': 0.02,
#   'surprise0': 0.41,
#   'neutral0': 0.02},
#  {'box0': [788, 237, 265, 343],
#   'angry0': 0.05,
#   'disgust0': 0.0,
#   'fear0': 0.05,
#   'happy0': 0.83,
#   'sad0': 0.0,
#   'surprise0': 0.05,
#   'neutral0': 0.01},
#  {'box0': [788, 238, 264, 341],
#   'angry0': 0.06,
#   'disgust0': 0.0,
#   'fear0': 0.05,
#   'happy0': 0.82,
#   'sad0': 0.0,
#   'surprise0': 0.05,
#   'neutral0': 0.01},
#  {'box0': [786, 232, 274, 352],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.01,
#   'happy0': 0.98,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [787, 232, 273, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.98,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [788, 231, 272, 351],
#   'angry0': 0.01,
#   'disgust0': 0.0,
#   'fear0': 0.01,
#   'happy0': 0.98,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [790, 228, 264, 351],
#   'angry0': 0.01,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.98,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [790, 228, 265, 351],
#   'angry0': 0.01,
#   'disgust0': 0.0,
#   'fear0': 0.01,
#   'happy0': 0.98,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [788, 227, 265, 351],
#   'angry0': 0.01,
#   'disgust0': 0.0,
#   'fear0': 0.01,
#   'happy0': 0.97,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [789, 227, 265, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.98,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [789, 227, 264, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.98,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [788, 225, 264, 351],
#   'angry0': 0.01,
#   'disgust0': 0.0,
#   'fear0': 0.01,
#   'happy0': 0.98,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [788, 225, 264, 351],
#   'angry0': 0.01,
#   'disgust0': 0.0,
#   'fear0': 0.01,
#   'happy0': 0.98,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [800, 232, 257, 339],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [799, 232, 258, 339],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.01,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [800, 232, 257, 339],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.01,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [798, 231, 257, 340],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [798, 231, 257, 340],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [797, 231, 257, 340],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [796, 230, 257, 341],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [796, 230, 257, 341],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [795, 230, 259, 341],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [795, 229, 259, 342],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [785, 228, 265, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.01,
#   'neutral0': 0.0},
#  {'box0': [785, 228, 265, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [785, 228, 265, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [783, 230, 267, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [783, 230, 267, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [782, 231, 267, 350],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [782, 231, 267, 350],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [782, 231, 267, 350],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [784, 230, 264, 350],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [784, 230, 264, 350],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [783, 231, 265, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [783, 231, 264, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [783, 231, 264, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [781, 231, 266, 350],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [782, 232, 263, 348],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [780, 231, 267, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [780, 231, 267, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [780, 231, 267, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [780, 231, 266, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [779, 231, 266, 349],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [776, 233, 270, 352],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [778, 232, 267, 353],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [777, 234, 269, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [777, 234, 269, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [777, 234, 268, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [778, 234, 268, 353],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [779, 234, 267, 353],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [779, 234, 267, 353],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [778, 234, 268, 355],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [777, 234, 269, 355],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [778, 235, 269, 354],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 1.0,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [779, 235, 268, 353],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [779, 235, 268, 353],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [778, 235, 269, 354],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [778, 235, 269, 354],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [777, 234, 271, 350],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [777, 234, 271, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [777, 234, 271, 351],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [779, 233, 268, 350],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [779, 233, 268, 350],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [781, 233, 267, 354],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [781, 233, 267, 354],
#   'angry0': 0.0,
#   'disgust0': 0.0,
#   'fear0': 0.0,
#   'happy0': 0.99,
#   'sad0': 0.0,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [781, 233, 267, 354],
# ...
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [789, 270, 269, 340],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.44,
#   'happy0': 0.0,
#   'sad0': 0.38,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [789, 270, 269, 340],
#   'angry0': 0.17,
#   'disgust0': 0.0,
#   'fear0': 0.44,
#   'happy0': 0.0,
#   'sad0': 0.38,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [789, 270, 271, 340],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.38,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [789, 270, 271, 340],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.38,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [789, 270, 271, 340],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.45,
#   'happy0': 0.0,
#   'sad0': 0.38,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [789, 270, 271, 340],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.52,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [789, 270, 271, 340],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.52,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [791, 270, 271, 339],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.48,
#   'happy0': 0.0,
#   'sad0': 0.37,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [791, 270, 271, 339],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.48,
#   'happy0': 0.0,
#   'sad0': 0.37,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [791, 270, 271, 339],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.48,
#   'happy0': 0.0,
#   'sad0': 0.37,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [792, 272, 270, 338],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.54,
#   'happy0': 0.0,
#   'sad0': 0.32,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [792, 272, 270, 338],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.54,
#   'happy0': 0.0,
#   'sad0': 0.32,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 272, 269, 337],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 272, 269, 337],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 272, 269, 337],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 271, 270, 338],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.29,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 272, 270, 337],
#   'angry0': 0.13,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.28,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 271, 270, 338],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 271, 270, 338],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 271, 270, 338],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 270, 270, 341],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 270, 270, 341],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 271, 269, 338],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.28,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 271, 269, 338],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.28,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [793, 271, 269, 338],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.28,
#   'surprise0': 0.0,
#   'neutral0': 0.0},
#  {'box0': [795, 270, 269, 338],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.29,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 270, 269, 338],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.56,
#   'happy0': 0.0,
#   'sad0': 0.29,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 266, 271, 344],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.62,
#   'happy0': 0.0,
#   'sad0': 0.27,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 266, 271, 344],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.61,
#   'happy0': 0.0,
#   'sad0': 0.27,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 266, 271, 344],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.61,
#   'happy0': 0.0,
#   'sad0': 0.27,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 268, 270, 341],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.26,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 268, 270, 341],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.25,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 268, 270, 343],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.28,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 268, 270, 343],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.28,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 268, 270, 343],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.28,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 268, 272, 341],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.25,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 268, 272, 341],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.25,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 266, 271, 344],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [795, 266, 271, 344],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [795, 266, 271, 344],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [794, 265, 271, 347],
#   'angry0': 0.06,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [794, 265, 271, 347],
#   'angry0': 0.06,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [795, 267, 272, 346],
#   'angry0': 0.08,
#   'disgust0': 0.0,
#   'fear0': 0.57,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [795, 267, 273, 346],
#   'angry0': 0.08,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [795, 267, 273, 346],
#   'angry0': 0.08,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [793, 267, 271, 348],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [792, 267, 273, 348],
#   'angry0': 0.07,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [794, 269, 270, 345],
#   'angry0': 0.08,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.35,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 269, 270, 345],
#   'angry0': 0.08,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.35,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 269, 270, 345],
#   'angry0': 0.08,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.35,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 269, 271, 346],
#   'angry0': 0.08,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [794, 270, 272, 344],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [794, 271, 270, 344],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.57,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 271, 271, 344],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.56,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 271, 271, 344],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.56,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 271, 272, 344],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.56,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 271, 271, 343],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.53,
#   'happy0': 0.0,
#   'sad0': 0.36,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 272, 272, 343],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 272, 270, 343],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 272, 270, 343],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 272, 272, 342],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.48,
#   'happy0': 0.0,
#   'sad0': 0.4,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 272, 271, 343],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.56,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 274, 270, 340],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.57,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 274, 270, 340],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.32,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 274, 270, 340],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.32,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 274, 270, 340],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.59,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 274, 270, 340],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.58,
#   'happy0': 0.0,
#   'sad0': 0.32,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 273, 270, 341],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.57,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 274, 270, 340],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.57,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 274, 270, 340],
#   'angry0': 0.09,
#   'disgust0': 0.0,
#   'fear0': 0.57,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 274, 273, 341],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.28,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 274, 273, 341],
#   'angry0': 0.1,
#   'disgust0': 0.0,
#   'fear0': 0.6,
#   'happy0': 0.0,
#   'sad0': 0.29,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 274, 272, 341],
#   'angry0': 0.11,
#   'disgust0': 0.0,
#   'fear0': 0.54,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 273, 271, 343],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.53,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 273, 271, 343],
#   'angry0': 0.12,
#   'disgust0': 0.0,
#   'fear0': 0.53,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [793, 271, 275, 344],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.52,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 271, 274, 344],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.52,
#   'happy0': 0.0,
#   'sad0': 0.31,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 272, 272, 342],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.53,
#   'happy0': 0.0,
#   'sad0': 0.32,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 272, 272, 342],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.53,
#   'happy0': 0.0,
#   'sad0': 0.32,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 272, 272, 342],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.53,
#   'happy0': 0.0,
#   'sad0': 0.32,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 270, 274, 345],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.52,
#   'happy0': 0.0,
#   'sad0': 0.33,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 270, 274, 345],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.52,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [795, 271, 273, 343],
#   'angry0': 0.15,
#   'disgust0': 0.0,
#   'fear0': 0.51,
#   'happy0': 0.0,
#   'sad0': 0.34,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 270, 274, 344],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 270, 274, 344],
#   'angry0': 0.14,
#   'disgust0': 0.0,
#   'fear0': 0.55,
#   'happy0': 0.0,
#   'sad0': 0.3,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 270, 273, 343],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.54,
#   'happy0': 0.0,
#   'sad0': 0.29,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [794, 270, 273, 343],
#   'angry0': 0.16,
#   'disgust0': 0.0,
#   'fear0': 0.54,
#   'happy0': 0.0,
#   'sad0': 0.29,
#   'surprise0': 0.0,
#   'neutral0': 0.01},
#  {'box0': [792, 265, 279, 348],
#   'angry0': 0.27,
#   'disgust0': 0.0,
#   'fear0': 0.49,
#   'happy0': 0.0,
#   'sad0': 0.22,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [792, 265, 279, 347],
#   'angry0': 0.28,
#   'disgust0': 0.0,
#   'fear0': 0.48,
#   'happy0': 0.0,
#   'sad0': 0.22,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [792, 265, 279, 347],
#   'angry0': 0.28,
#   'disgust0': 0.0,
#   'fear0': 0.49,
#   'happy0': 0.0,
#   'sad0': 0.22,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [792, 265, 278, 347],
#   'angry0': 0.3,
#   'disgust0': 0.0,
#   'fear0': 0.44,
#   'happy0': 0.0,
#   'sad0': 0.24,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [792, 265, 278, 347],
#   'angry0': 0.3,
#   'disgust0': 0.0,
#   'fear0': 0.44,
#   'happy0': 0.0,
#   'sad0': 0.24,
#   'surprise0': 0.0,
#   'neutral0': 0.02},
#  {'box0': [791, 262, 278, 349],
#   'angry0': 0.32,
#   'disgust0': 0.0,
#   'fear0': 0.38,
#   'happy0': 0.0,
#   'sad0': 0.24,
#   'surprise0': 0.01,
#   'neutral0': 0.04},
#  {'box0': [791, 262, 278, 349],
#   'angry0': 0.33,
#   'disgust0': 0.0,
#   'fear0': 0.38,
#   'happy0': 0.0,
#   'sad0': 0.24,
#   'surprise0': 0.01,
#   'neutral0': 0.04},
#  {'box0': [791, 262, 278, 349],
#   'angry0': 0.33,
#   'disgust0': 0.0,
#   'fear0': 0.38,
#   'happy0': 0.0,
#   'sad0': 0.24,
#   'surprise0': 0.01,
#   'neutral0': 0.04},
#  {'box0': [791, 262, 277, 347],
#   'angry0': 0.34,
#   'disgust0': 0.0,
#   'fear0': 0.35,
#   'happy0': 0.0,
#   'sad0': 0.25,
#   'surprise0': 0.01,
#   'neutral0': 0.05},
#  {'box0': [791, 262, 278, 347],
#   'angry0': 0.34,
#   'disgust0': 0.0,
#   'fear0': 0.33,
#   'happy0': 0.0,
#   'sad0': 0.26,
#   'surprise0': 0.02,
#   'neutral0': 0.05},
#  {'box0': [791, 259, 279, 348],
#   'angry0': 0.35,
#   'disgust0': 0.0,
#   'fear0': 0.33,
#   'happy0': 0.0,
#   'sad0': 0.23,
#   'surprise0': 0.03,
#   'neutral0': 0.06},
#  {'box0': [791, 260, 279, 347],
#   'angry0': 0.37,
#   'disgust0': 0.0,
#   'fear0': 0.3,
#   'happy0': 0.0,
#   'sad0': 0.23,
#   'surprise0': 0.03,
#   'neutral0': 0.07},
#  {'box0': [791, 259, 279, 349],
#   'angry0': 0.35,
#   'disgust0': 0.0,
#   'fear0': 0.33,
#   'happy0': 0.0,
#   'sad0': 0.23,
#   'surprise0': 0.03,
#   'neutral0': 0.06}]

# %%
from fer import Video
from fer import FER
import os
import sys
import pandas as pd
# Put in the location of the video file that has to be processed
location_videofile = "Video_One.mp4"

# %%
# But the Face detection detector
face_detector = FER(mtcnn=True)
# Input the video for processing
input_video = Video(location_videofile)

# %%
processing_data = input_video.analyze(face_detector, display=False)
# Out:
# INFO:fer:30.00 fps, 583 frames, 19.43 seconds
# INFO:fer:Making directories at output
# INFO:fer:Deleted pre-existing output/Video_One_output.mp4
#   0%|                                               | 0/583 [00:00<?, ?frames/s]2022-08-10 15:10:13.090370: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 15:10:13.309001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 15:10:13.430122: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 15:10:13.896907: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 15:10:13.982100: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 100%|█████████████████████████████████████| 583/583 [04:01<00:00,  2.42frames/s]
# INFO:fer:Completed analysis: saved to output/Video_One_output.mp4
# INFO:fer:Starting to Zip
# INFO:fer:Compressing: 8%
# INFO:fer:Compressing: 17%
# INFO:fer:Compressing: 25%
# INFO:fer:Compressing: 34%
# INFO:fer:Compressing: 42%
# INFO:fer:Compressing: 51%
# INFO:fer:Compressing: 60%
# INFO:fer:Compressing: 68%
# INFO:fer:Compressing: 77%
# INFO:fer:Compressing: 85%
# INFO:fer:Compressing: 94%
# INFO:fer:Zip has finished

# %%
# We will now convert the analysed information into a dataframe.
# This will help us import the data as a .CSV file to perform analysis over it later
vid_df = input_video.to_pandas(processing_data)
vid_df = input_video.get_first_face(vid_df)
vid_df = input_video.get_emotions(vid_df)

# Plotting the emotions against time in the video
pltfig = vid_df.plot(figsize=(20, 8), fontsize=16).get_figure()

# %%
# We will now work on the dataframe to extract which emotion was prominent in the video
angry = sum(vid_df.angry)
disgust = sum(vid_df.disgust)
fear = sum(vid_df.fear)
happy = sum(vid_df.happy)
sad = sum(vid_df.sad)
surprise = sum(vid_df.surprise)
neutral = sum(vid_df.neutral)

emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
emotions_values = [angry, disgust, fear, happy, sad, surprise, neutral]

score_comparisons = pd.DataFrame(emotions, columns = ['Human Emotions'])
score_comparisons['Emotion Value from the Video'] = emotions_values
score_comparisons
# Out:
#   Human Emotions  Emotion Value from the Video
# 0          Angry                         76.83
# 1        Disgust                          0.00
# 2           Fear                        159.33
# 3          Happy                        165.29
# 4            Sad                         87.00
# 5       Surprise                         25.21
# 6        Neutral                         67.95

# %%
location_videofile1 = "Video_Two.mp4"
face_detector = FER(mtcnn=True)
# Input the video for processing
input_video = Video(location_videofile1)

# %%
processing_data = input_video.analyze(face_detector, display=False)
# Out:
# INFO:fer:30.00 fps, 458 frames, 15.27 seconds
# INFO:fer:Making directories at output
#   0%|                                               | 0/458 [00:00<?, ?frames/s]2022-08-10 15:20:55.451256: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 15:20:55.619579: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 15:20:55.721328: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 15:20:56.252023: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-08-10 15:20:56.341839: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 100%|█████████████████████████████████████| 458/458 [03:10<00:00,  2.40frames/s]
# INFO:fer:Completed analysis: saved to output/Video_Two_output.mp4
# INFO:fer:Starting to Zip
# INFO:fer:Compressing: 10%
# INFO:fer:Compressing: 21%
# INFO:fer:Compressing: 32%
# INFO:fer:Compressing: 43%
# INFO:fer:Compressing: 54%
# INFO:fer:Compressing: 65%
# INFO:fer:Compressing: 76%
# INFO:fer:Compressing: 87%
# INFO:fer:Compressing: 98%
# INFO:fer:Zip has finished

# %%
# We will now convert the analysed information into a dataframe.
# This will help us import the data as a .CSV file to perform analysis over it later
vid_df = input_video.to_pandas(processing_data)
vid_df = input_video.get_first_face(vid_df)
vid_df = input_video.get_emotions(vid_df)

# Plotting the emotions against time in the video
pltfig = vid_df.plot(figsize=(20, 8), fontsize=16).get_figure()

# %%
# We will now work on the dataframe to extract which emotion was prominent in the video
angry = sum(vid_df.angry)
disgust = sum(vid_df.disgust)
fear = sum(vid_df.fear)
happy = sum(vid_df.happy)
sad = sum(vid_df.sad)
surprise = sum(vid_df.surprise)
neutral = sum(vid_df.neutral)

emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
emotions_values = [angry, disgust, fear, happy, sad, surprise, neutral]

score_comparisons = pd.DataFrame(emotions, columns = ['Human Emotions'])
score_comparisons['Emotion Value from the Video'] = emotions_values
score_comparisons
# Out:
#   Human Emotions  Emotion Value from the Video
# 0          Angry                         21.62
# 1        Disgust                          0.00
# 2           Fear                         33.87
# 3          Happy                        137.53
# 4            Sad                         82.54
# 5       Surprise                         14.49
# 6        Neutral                        167.79
